# %% [markdown]
# # LSST SRD Redshift Distributions and Tomographic Binning
#
# This notebook generates **LSST SRD** (Science Requirements Document) redshift distributions for **source** and **lens** galaxy samples, and performs **tomographic binning** for different LSST forecast years (Y1, Y4, Y7, Y10).
#
# ## Authors
#
# **LSST DESC Collaboration**
#
# ## Key Parameters
#
# | Parameter               | Value / Description                        |
# |-------------------------|--------------------------------------------|
# | **Forecast Years**       | `"1"`, `"4"`, `"7"`, `"10"`               |
# | **Default Redshift Range** | `np.linspace(0, 3.5, 500)`               |
# | **Lens Bin Range**       | 0.01 to 1.5                                |
# | **Normalization**        | All distributions normalized by default   |
# | **Bin Center Precision** | 3 decimal places                            |
#
# ## References
#
# - **Primary Reference:**
#   [LSST DESC Science Requirements Document (SRD)](https://arxiv.org/abs/1809.01669)
# - **Original Notebook:**
#   [LSST_SRD_Redshift_Distributions_and_Binning.ipynb](https://github.com/LSSTDESC/CCLX/blob/master/LSST_SRD_Redshift_Distributions_and_Binning.ipynb)
# - **Additional References:**
#   [Ma, Hu & Huterer 2005](https://arxiv.org/abs/astro-ph/0506614) – Photometric redshift analysis
#
# ## License
#
# This work is part of the LSST Dark Energy Science Collaboration (DESC) project.

# %% [markdown]
# # Code Functionality Steps
#
# ## Main Components
#
# - **Redshift Distribution Modeling**: Generates photometric redshift distributions for LSST survey based on the Smail et al. formula (n(z) ∝ z² exp[-(z/z₀)^β])
#
# - **Forecast Year Configurations**: Defines survey depth parameters (z₀, β, i-band limiting magnitude) for years 1, 4, 7, and 10 of LSST operations
#
# - **Tomographic Binning**: Divides galaxy samples into redshift bins (typically 5 bins) for weak lensing analysis using equal number density splitting
#
# - **Bin Statistics Calculation**: Computes mean redshift, median redshift, and effective number density for each tomographic bin
#
# - **Visualization Functions**:
#   - Plots n(z) distributions for different forecast years
#   - Shows tomographic bin divisions with shaded regions
#   - Overlays lens and source redshift distributions
#
# - **Normalization & Integration**: Uses numerical integration (Simpson's rule) to normalize distributions and calculate cumulative distributions for binning
#
# - **Output Generation**: Produces formatted tables with bin edges, central values, and statistical properties for each forecast configuration
#
# - **Lens-Source Analysis**: Compares foreground lens galaxy distributions with background source distributions for lensing efficiency calculations

# %% [markdown]
# ### **Overview**
#
# 1. The notebook **generates simulated redshift distributions** for galaxies expected to be observed by the LSST survey.
# 2. It **segments galaxies into tomographic bins** based on their redshift, facilitating the study of large-scale structure evolution over cosmic time.
# 3. It **computes the mean redshift of each bin**, providing representative values for subsequent modeling and analysis.
# 4. It **visualizes the distributions and binning results** to enable verification and interpretation of the data.
# 5. It **saves the resulting datasets**, making them available for further cosmological analyses, including studies of gravitational lensing and galaxy clustering.
#
#
# ### **Purpose (Key Objectives)**
#
# * **Simulation of LSST Observations:** Generate realistic galaxy redshift distributions for multiple survey epochs (Y1, Y4, Y7, Y10).
# * **Tomographic Binning:** Organize galaxies into redshift bins, accounting for photometric uncertainties, to support cosmological investigations.
# * **Determination of Weighted Bin Centers:** Compute representative redshifts for each bin to facilitate subsequent analyses.
# * **Data Visualization:** Produce plots for the inspection of distributions and bin assignments, ensuring accuracy and consistency.
# * **Data Preservation:** Store distributions and bin information for downstream analyses, such as weak lensing forecasts and galaxy clustering studies.
#
#
# ### **Significance**
#
# * Enables researchers to **prepare for LSST data analyses** prior to the availability of actual observations.
# * Supports **forecasting for weak lensing, galaxy clustering, and other cosmological probes**.
# * Provides **ready-to-use simulated redshift samples** for integration into cosmological simulation pipelines.

# %% [markdown]
# - ## Imports visualization tools and the `LSSTGalaxySample` class for LSST galaxy data analysis.

# %%
import cmasher as cmr
import matplotlib.pyplot as plt
import numpy as np
from lsst_galaxy_sample import LSSTGalaxySample as lsst

# %% [markdown]
# ## The SRD Redshift Distributions
#
# The overall redshift distribution of galaxies for LSST follows a **Smail-type parameterization**:
#
# \begin{equation}
# p (z) = \left( \frac{z}{z_0}  \right) ^\beta \exp \left[ - \left( \frac{z}{z_0}  \right) ^\alpha\right] ,
# \end{equation}
#
# where $ z $ is the redshift, $ z_0 $ is the pivot redshift, and $ \alpha $ and $ \beta $ are power-law indices. The pivot redshift and power-law indices differ between lens and source galaxies and depend on the forecast year. These values are stored in the `lsst_desc_parameters.yaml` file, with details available in the [LSST DESC Science Requirements Document (SRD)](https://arxiv.org/abs/1809.01669).
#
# This function represents the **normalized** probability distribution $ p(z) $, ensuring:
#
# \begin{equation}
# \int p(z) \, dz = 1.
# \end{equation}
#
# This is the only quantity passed to CCL, as CCL normalizes all inputs internally. We do not apply a separate scaling factor such as $ n_{\text{gal}} $.
#
# ## Tomographic Bins
#
# For tomographic binning, the observed redshift distribution accounts for photometric uncertainties by convolving the intrinsic redshift distribution with a photometric error model.
# For a Gaussian photo-$z$ scatter and a top-hat selection in photometric redshift, the result of this convolution is:
#
# \begin{equation}
# n_i(z) = \frac{1}{2} n(z) \left[ \operatorname{erf} \left( \frac{z_{\text{ph}}^{(i+1)} - z + z_{\text{bias}}}{\sqrt{2} \sigma_z} \right) - \operatorname{erf} \left( \frac{z_{\text{ph}}^{(i)} - z + z_{\text{bias}}}{\sqrt{2} \sigma_z} \right) \right] .
# \end{equation}
#
# Here, $ z_{\text{bias}} $ is the photometric bias and $ \sigma_z $ is the photometric scatter, both of which depend on the galaxy sample (lens or source). For more details, see [Ma, Hu & Huterer 2005](https://arxiv.org/abs/astro-ph/0506614).
#
# For lens galaxies, the tomographic bins are defined by fixed redshift intervals, while source galaxies are divided into bins containing an equal number of galaxies. The bin edges for source galaxies are determined by integrating the cumulative redshift distribution and selecting boundaries that ensure equal galaxy counts in each bin.
#
# ## Tomographic Bin Centers
#
# For both **lens** and **source** galaxy samples, the bin centers are computed using a **weighted mean redshift** within each tomographic bin. This is done using numerical integration.
#
# The center of each tomographic bin $i$ is given by:
#
# \begin{equation}
# z_{\text{center}, i} = \frac{\int z \, p_i(z) \, dz}{\int p_i(z) \, dz}
# \end{equation}
#
# where:
# - $p_i(z)$ is the redshift distribution in the $i$-th tomographic bin.
# - The numerator computes the **weighted sum of redshifts** in the bin.
# - The denominator ensures proper **normalization**.
#
# This approach ensures that the bin centers represent the **weighted average redshift** of galaxies in each tomographic bin.

# %% [markdown]
# ## Generating the Data
#
# The `LSSTGalaxySample` class provides key redshift distribution products for LSST forecasts, including:
#
# - **Lens and source samples** (`numpy.ndarray`): The redshift distributions of lens and source galaxies (Smail type distribution, unbinned).
# - **Tomographically binned samples** (`dict`): Redshift distributions split into lens and source bins.
# - **Bin centers** (`dict`): Frequently used in analyses, these are readily available in the code
#
# The class supports all relevant LSST forecast years and is initialized with:
# 1. **Forecast year** (required, as `str`) – available options: `"1"`, `"4"`, `"7"`, and `"10"`.
# 2. **Redshift range** (optional, as `array`) – if not provided, the default is: $ \text{redshift\_range} = \text{np.linspace}(0, 3.5, 500) $
#
# Below, we generate the redshift distributions and tomographic bins for the LSST source and lens samples.
#
# By default:
# - All distributions, including $N(z)$ and tomographic bins, are **normalized**.
# - Tomo bin centers are rounded to **two decimal places**.
# - The generated files are **automatically saved**.
#
# The arguments are explicitly specified below for clarity, though they reflect the default behavior.

# %% [markdown]
# - ## Generates and stores LSST redshift distributions, tomographic bins, and bin centers for multiple forecast years in a dictionary.

# %%
# Define the redshift interval and forecast years
redshift_range = np.linspace(0.0, 3.5, 500)
forecast_years = ["1", "4", "7", "10"]  # LSST forecasting epochs
samples = {}

# Loop over forecast years and store the data into a dictionary
for year in forecast_years:
    init = lsst(year, redshift_range)
    samples[year] = {
        "source_nz": init.source_sample(normalized=True, save_file=True),
        "lens_nz": init.lens_sample(normalized=True, save_file=True),
        "source_bins": init.source_bins(normalized=True, save_file=True),
        "lens_bins": init.lens_bins(normalized=True, save_file=True),
        "source_bin_centers": init.source_bin_centers(decimal_places=3),
        "lens_bin_centers": init.lens_bin_centers(decimal_places=3)
    }

# If you want to access the redshift distributions, tomographic bins and bin centers
# for LSST Y1 source sample, you can do so by calling the following (uncomment the ines below):
# source_sample_y1 = samples["1"]["source_nz"]  # to get the Y1 source N(z)
# lens_bins_y1 = samples["1"]["lens_bins"]  # to get the Y1 lens bins
# lens_bin_centers_y10 = samples["10"]["lens_bin_centers"]  # to get the Y10 centers of lens bins

# %% [markdown]
# # Plot the Results

# %% [markdown]
# - ## Sets up plot styling parameters and defines color palettes for LSST lens and source samples across forecast years.

# %%
# Let us set up some plotting params here
plt.rcParams.update({
    "lines.linewidth": 3,
    "axes.labelsize": 25,
    "axes.titlesize": 28,
    "xtick.labelsize": 20,
    "ytick.labelsize": 20,
    "legend.fontsize": 15
})

# Define colors for plots
colors = {
    "lenses": {
        "1": cmr.take_cmap_colors('cmr.freeze', len(samples["1"]["lens_bins"]),
                                  cmap_range=(0.2, 0.85), return_fmt='hex'),
        "10": cmr.take_cmap_colors('cmr.freeze', len(samples["10"]["lens_bins"]),
                                   cmap_range=(0.2, 0.85), return_fmt='hex'),
        "4": cmr.take_cmap_colors('cmr.freeze', len(samples["4"]["lens_bins"]),
                                  cmap_range=(0.2, 0.85), return_fmt='hex'),
        "7": cmr.take_cmap_colors('cmr.freeze', len(samples["7"]["lens_bins"]),
                                  cmap_range=(0.2, 0.85), return_fmt='hex'),
    },
    "sources": {
        "1": cmr.take_cmap_colors('cmr.ember', len(samples["1"]["source_bins"]),
                                  cmap_range=(0.2, 0.85), return_fmt='hex'),
        "10": cmr.take_cmap_colors('cmr.ember', len(samples["10"]["source_bins"]),
                                   cmap_range=(0.2, 0.85), return_fmt='hex'),
        "4": cmr.take_cmap_colors('cmr.ember', len(samples["4"]["source_bins"]),
                                  cmap_range=(0.2, 0.85), return_fmt='hex'),
        "7": cmr.take_cmap_colors('cmr.ember', len(samples["7"]["source_bins"]),
                                  cmap_range=(0.2, 0.85), return_fmt='hex'),
    }
}

# %% [markdown]
# - ## Plots LSST source and lens redshift distributions for different forecast years side by side with customized colors and styling.

# %%
# Key mapping for new method
key_map = {'sources': "source_nz",
           'lenses': "lens_nz"}
norm_key = "normalized"
titles = {'sources': f'LSST Source Sample \n {norm_key}',
          'lenses': f'LSST Lens Sample \n {norm_key}'}

# Create 1x2 grid of subplots (one for sources, one for lenses)
fig, axs = plt.subplots(1, 2, figsize=(18, 7), sharex=True)
lw=4

# Loop through sample types and overlay both methods
for ax, sample_type in zip(axs, ["lenses", "sources"]):
    # Select second and second-to-last colors from the colormap lists
    y1_color = colors[sample_type]["1"][-2]
    y4_color = colors[sample_type]["4"][-2]
    y7_color = colors[sample_type]["7"][-2]
    y10_color = colors[sample_type]["10"][2]

    ax.plot(redshift_range, samples["1"][key_map[sample_type]], label='Y1', color=y1_color, lw=lw)
    ax.plot(redshift_range, samples["4"][key_map[sample_type]], label='Y4', color=y4_color, lw=lw)
    ax.plot(redshift_range, samples["7"][key_map[sample_type]], label='Y7', color=y7_color, lw=lw)
    ax.plot(redshift_range, samples["10"][key_map[sample_type]], label='Y10', color=y10_color, lw=lw)

    # Labels & styling
    ax.set_title(titles[sample_type])
    ax.set_xlabel('redshift')
    ax.set_ylabel('redshift distribution')
    ax.tick_params(direction='in')
    ax.legend(frameon=False)

# Adjust layout and show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Plot the Tomographic Bins
# Plot the results to inspect visually. We will only plot the normalized bins. You can plot the unnormalized ones but simply loading the data from the `samples_unnormalized` dictionary.
#
# ### Lens Tomo Bins

# %% [markdown]
# - # Plots LSST lens tomographic bins for each forecast year in a 2×2 grid with customized colors and labels.

# %%
# Define parameters
years = ["1", "4", "7", "10"]
bin_type = "lens_bins"
sample_type = "lenses"

fig, axes = plt.subplots(2, 2, figsize=(16, 10))
axes = axes.flatten()
lw=4

for idx, year in enumerate(years):
    ax = axes[idx]
    for bin_idx, (key, data) in enumerate(samples[year][bin_type].items()):
        ax.plot(redshift_range,
                data,
                label=f"bin {key+1}",
                color=colors[sample_type][year][bin_idx],
                linestyle='-',
                lw=lw)

    ax.set_xlim(0.01, 1.5)  # Set the x-axis limits since lens bins are defined in this range
    ax.set_xlabel("redshift")
    ax.set_ylabel("redshift distribution")
    ax.set_title(f"Lens bins for LSST Y{year}")
    ax.tick_params(direction='in')
    ax.legend(frameon=False, ncol=1)
    ax.tick_params(axis='both', which='major')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Source Tomo Bins

# %% [markdown]
# - ## Plots LSST source tomographic bins for each forecast year in a 2×2 grid with distinct colors and labels.

# %%
# Define parameters
years = ["1", "4", "7", "10"]
bin_type = "source_bins"
sample_type = "sources"

fig, axes = plt.subplots(2, 2, figsize=(16, 10))
axes = axes.flatten()
lw=4

for idx, year in enumerate(years):
    ax = axes[idx]
    for bin_idx, (key, data) in enumerate(samples[year][bin_type].items()):
        ax.plot(redshift_range,
                data,
                label=f"bin {key+1}",
                color=colors[sample_type][year][bin_idx],
                linestyle='-',
                lw=lw)

    ax.set_xlabel("redshift")
    ax.set_ylabel("redshift distribution")
    ax.set_title(f"Source bins for LSST Y{year}")
    ax.tick_params(direction='in')
    ax.legend(frameon=False, ncol=1)
    ax.tick_params(axis='both', which='major')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Print the bin centers
# Finally, we print the bin centers for the source and lens samples for LSST Y1 and Y10.

# %% [markdown]
# - ## Prints the redshift bin centers for LSST source and lens samples across all forecast years.

# %%
# Print the bin centers
print(f"Source bin centers for Y1: {samples['1']['source_bin_centers']}")
print(f"Source bin centers for Y4: {samples['4']['source_bin_centers']}")
print(f"Source bin centers for Y7: {samples['7']['source_bin_centers']}")
print(f"Source bin centers for Y10: {samples['10']['source_bin_centers']}")

print(f"Lens bin centers for Y1: {samples['1']['lens_bin_centers']}")
print(f"Lens bin centers for Y4: {samples['4']['lens_bin_centers']}")
print(f"Lens bin centers for Y7: {samples['7']['lens_bin_centers']}")
print(f"Lens bin centers for Y10: {samples['10']['lens_bin_centers']}")
# Out:
# Source bin centers for Y1: {0: 0.251, 1: 0.456, 2: 0.655, 3: 0.917, 4: 1.527}
# Source bin centers for Y4: {0: 0.256, 1: 0.472, 2: 0.682, 3: 0.962, 4: 1.614}
# Source bin centers for Y7: {0: 0.296, 1: 0.558, 2: 0.815, 3: 1.159, 4: 1.927}
# Source bin centers for Y10: {0: 0.309, 1: 0.589, 2: 0.867, 3: 1.241, 4: 2.053}
# Lens bin centers for Y1: {0: 0.317, 1: 0.506, 2: 0.7, 3: 0.896, 4: 1.093}
# Lens bin centers for Y4: {0: 0.318, 1: 0.507, 2: 0.701, 3: 0.898, 4: 1.095}
# Lens bin centers for Y7: {0: 0.262, 1: 0.358, 2: 0.456, 3: 0.554, 4: 0.653, 5: 0.752, 6: 0.851, 7: 0.95, 8: 1.049, 9: 1.148}
# Lens bin centers for Y10: {0: 0.263, 1: 0.359, 2: 0.456, 3: 0.555, 4: 0.653, 5: 0.752, 6: 0.851, 7: 0.95, 8: 1.049, 9: 1.149}

# %% [markdown]
# - ## Prints LSST lens and source bin centers as simple lists for each forecast year.

# %%
# If you wish to just print the bin centers as lists, you can do it this way:
for year in ["1", "4", "7", "10"]:
    lens_bin_centers = list(samples[year]["lens_bin_centers"].values())
    print(f"Lens bin centers for Y{year}: {lens_bin_centers}")

print("----------------------------------------")

for year in ["1", "4", "7", "10"]:
    source_bin_centers = list(samples[year]["source_bin_centers"].values())
    print(f"Source bin centers for Y{year}: {source_bin_centers}")
# Out:
# Lens bin centers for Y1: [0.317, 0.506, 0.7, 0.896, 1.093]
# Lens bin centers for Y4: [0.318, 0.507, 0.701, 0.898, 1.095]
# Lens bin centers for Y7: [0.262, 0.358, 0.456, 0.554, 0.653, 0.752, 0.851, 0.95, 1.049, 1.148]
# Lens bin centers for Y10: [0.263, 0.359, 0.456, 0.555, 0.653, 0.752, 0.851, 0.95, 1.049, 1.149]
# ----------------------------------------
# Source bin centers for Y1: [0.251, 0.456, 0.655, 0.917, 1.527]
# Source bin centers for Y4: [0.256, 0.472, 0.682, 0.962, 1.614]
# Source bin centers for Y7: [0.296, 0.558, 0.815, 1.159, 1.927]
# Source bin centers for Y10: [0.309, 0.589, 0.867, 1.241, 2.053]

# %% [markdown]
# - ## Plots LSST lens bins for each forecast year and marks their tomographic bin centers with dashed vertical lines.

# %%
# Lastly, let us also mark the tomo bin centers onto the source and lens bin plots.
# First we plot the lens bins and then the source bins with the centers marked.

# Define parameters
years = ["1", "4", "7", "10"]
bin_type = "lens_bins"
sample_type = "lenses"

fig, axes = plt.subplots(2, 2, figsize=(18, 12))
axes = axes.flatten()
lw = 4

for idx, year in enumerate(years):
    ax = axes[idx]

    # Compute the global max for proper y-limits
    global_max = max([max(data) for data in samples[year][bin_type].values()])
    ax.set_ylim(0, global_max * 1.1)

    for bin_idx, (key, data) in enumerate(samples[year][bin_type].items()):
        # Mark the bin centers with vertical lines extending precisely to each bin's max
        center = samples[year]["lens_bin_centers"][key]
        max_bin_value = max(data)  # Peak of this bin
        ax.axvline(center,
                   color=colors[sample_type][year][bin_idx],
                   linestyle='--',
                   lw=2,
                   ymin=0,
                   ymax=max_bin_value / (global_max * 1.1))

        ax.plot(redshift_range,
                data,
                label=rf"$z_\mathrm{{center}}^{key+1}={center:.3f}$",
                color=colors[sample_type][year][bin_idx],
                linestyle='-',
                lw=lw)

    ax.set_xlim(0.01, 1.5)  # Set x-axis limits since lens bins are defined in this range
    ax.set_xlabel("redshift")
    ax.set_ylabel("redshift distribution")
    ax.set_title(f"Lens bins for LSST Y{year}")
    ax.tick_params(direction='in')
    ax.legend(frameon=False, ncol=1)
    ax.tick_params(axis='both', which='major')

plt.tight_layout()
plt.show()

# %% [markdown]
# - # Plots LSST source bins for each forecast year and marks their tomographic bin centers with dashed vertical lines.

# %%
# Define parameters
years = ["1", "4", "7", "10"]
bin_type = "source_bins"
sample_type = "sources"

fig, axes = plt.subplots(2, 2, figsize=(18, 12))
axes = axes.flatten()
lw = 4

for idx, year in enumerate(years):
    ax = axes[idx]

    # Compute the global max for proper y-limits
    global_max = max([max(data) for data in samples[year][bin_type].values()])
    ax.set_ylim(0, global_max * 1.1)  # Ensure the tallest bin fits well

    for bin_idx, (key, data) in enumerate(samples[year][bin_type].items()):
        # Mark the bin centers with vertical lines extending precisely to each bin's max
        center = samples[year]["source_bin_centers"][key]
        max_bin_value = max(data)  # Peak of this bin
        ax.axvline(center,
                   color=colors[sample_type][year][bin_idx],
                   linestyle='--',
                   lw=2,
                   ymin=0,
                   ymax=max_bin_value / (global_max * 1.1))  # Prevent overshoot

        ax.plot(redshift_range,
                data,
                label=rf"$z_\mathrm{{center}}^{key+1}={center:.3f}$",
                color=colors[sample_type][year][bin_idx],
                linestyle='-',
                lw=lw)

    ax.set_xlabel("redshift")
    ax.set_ylabel("redshift distribution")
    ax.set_title(f"Source bins for LSST Y{year}")
    ax.tick_params(direction='in')
    ax.legend(frameon=False, ncol=1)
    ax.tick_params(axis='both', which='major')

plt.tight_layout()
plt.show()
